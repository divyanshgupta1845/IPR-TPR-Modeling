# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.optimize import fsolve
# %run IPR.ipynb
# %run VLP.ipynb
# %run Interpolation.ipynb
# %run skin_effect.ipynb
# %run tubing_effect.ipynb
# %run Pwf_eff.ipynb
# %run diff_API_tubing.ipynb
# Out:
# Operating Condition: ( Qo (STB/day), Pwf (psi) ) = (885.40, 927.03)
# Operating Condition: ( Qo (STB/day), Pwf (psi) ) = (885.40, 927.03)
# New Operating Condition: ( Qo (STB/day), Pwf (psi) ) = (1435.74, 1019.19)
# Operating Condition: ( Qo (STB/day), Pwf (psi) ) = (885.40, 927.03)
# New Operating Condition: ( Qo (STB/day), Pwf (psi) ) = ( 847.47 , 1070.35 )
# New Operating Condition: ( Qo (STB/day), Pwf (psi) ) = (926.44, 750.37)
# Operating Condition: ( Qo (STB/day), Pwf (psi) ) = (885.40, 927.03)
# New Operating Condition: ( Qo (STB/day), Pwf (psi) ) = ( 847.47 , 1070.35 )
# Operating Condition for 1.05 inch tubing: ( Qo (STB/day), Pwf (psi) ) = ( 509.48 , 1974.76 )
# Operating Condition for 1.315 inch tubing: ( Qo (STB/day), Pwf (psi) ) = ( 665.81 , 1613.04 )
# Operating Condition for 1.66 inch tubing: ( Qo (STB/day), Pwf (psi) ) = ( 786.30 , 1274.94 )
# Operating Condition for 1.9 inch tubing: ( Qo (STB/day), Pwf (psi) ) = ( 833.44 , 1119.93 )
# Optimum Tubing Size is 1.9 inch
